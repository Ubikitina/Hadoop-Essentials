# %% [markdown]
# # Parquet Fundamentals

# %% [markdown]
# ## Download dataset
#
# **Conversion to Parquet and Schema Extraction**
#
# Like other formats, Apache Parquet can be read and interpreted using the Pandas library in Python. We will convert the file `convocatorias-2020.csv` to Parquet.

# %%
! mkdir -p /media/notebooks/argentina

# Download CSV file                        
! wget https://github.com/Vega90/datasets/raw/main/convocatorias-2020.csv \
-O /media/notebooks/argentina/convocatorias-2020.csv
# Out:
# --2024-11-10 15:32:37--  https://github.com/Vega90/datasets/raw/main/convocatorias-2020.csv
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Vega90/datasets/main/convocatorias-2020.csv [following]
# --2024-11-10 15:32:38--  https://raw.githubusercontent.com/Vega90/datasets/main/convocatorias-2020.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5675992 (5.4M) [text/plain]
# Saving to: ‘/media/notebooks/argentina/convocatorias-2020.csv’
#
# /media/notebooks/ar 100%[===================>]   5.41M  4.14MB/s    in 1.3s
#
# 2024-11-10 15:32:39 (4.14 MB/s) - ‘/media/notebooks/argentina/convocatorias-2020.csv’ saved [5675992/5675992]

# %% [markdown]
# ## Parquet file creation with Pandas

# %% [markdown]
# Now, Pandas allows us to directly write to Parquet format using `pd.to_parquet('path')`.

# %%
import pandas as pd

columnas = [
             'numero_procedimiento', 'nro_saf', 'descripcion_saf', 'nro_uoc', 
             'descripcion_uoc','tipo_de_procedimiento', 'modalidad', 'apartado_directa', 
             'ejercicio', 'fecha_de_publicacion', 'fecha_de_apertura', 'etapa', 'alcance', 
             'nombre_del_procedimiento', 'objeto_del_procedimiento', 'monto_estimado', 'tipo_de_operacion'
           ]

df_convocatorias = pd.read_csv('/media/notebooks/argentina/convocatorias-2020.csv', names=columnas)                       

df_convocatorias.head(3)
# Out:
#   numero_procedimiento  nro_saf  \
# 0     40/51-0159-LPR19      381
# 1        22-0041-CDI19      250
# 2     40/51-0918-CDI19      381
#
#                                      descripcion_saf  nro_uoc  \
# 0      381 - Estado Mayor General de La Fuerza Aérea       40
# 1  250 - Caja de Retiros Jubilaciones y Pensiones...       22
# 2      381 - Estado Mayor General de La Fuerza Aérea       40
#
#                                      descripcion_uoc tipo_de_procedimiento  \
# 0    Departamento Contrataciones Córdoba - UOC 40/51    Licitacion Privada
# 1  22 - Dpto de Compras y Suministros - Caja de R...  Contratación Directa
# 2    Departamento Contrataciones Córdoba - UOC 40/51  Contratación Directa
#
#        modalidad                          apartado_directa  ejercicio  \
# 0  Sin Modalidad                                       NaN       2019
# 1  Sin Modalidad  Apartado 1: Compulsa Abreviada Por Monto       2019
# 2  Sin Modalidad  Apartado 1: Compulsa Abreviada Por Monto       2019
#
#        fecha_de_publicacion         fecha_de_apertura  etapa   alcance  \
# 0  02/01/2020 08:00:00 a.m.  10/01/2020 10:00:00 a.m.  Única  Nacional
# 1  02/01/2020 12:00:00 p.m.  13/01/2020 09:00:00 a.m.  Única  Nacional
# 2  02/01/2020 12:00:00 p.m.  13/01/2020 10:00:00 a.m.  Única  Nacional
#
#                             nombre_del_procedimiento  \
# 0  “Adquisición de Elementos de Librería para el ...
# 1  Servicio de seguridad de información sensible ...
# 2  “Servicio Médico Asistencial para Organismos V...
#
#                             objeto_del_procedimiento  monto_estimado  \
# 0  “Adquisición de Elementos de Librería para el ...      1957142.84
# 1  Servicio de seguridad de información sensible ...       119915.25
# 2  “Servicio Médico Asistencial para Organismos V...        99000.00
#
#    tipo_de_operacion
# 0  Proceso de Compra
# 1  Proceso de Compra
# 2  Proceso de Compra

# %% [markdown]
# We convert to parquet format:

# %%
# conversion to parquet of the first lines
df_convocatorias.to_parquet('/media/notebooks/argentina/convocatorias-2020.parq')

# Display parquet file
! cat /media/notebooks/argentina/convocatorias-2020.parq | tail
# Out:
# �ƨP��:�Ҩ5��z��9��:Z��<j����@j�*��Dj�j��Hj���.�Lj��>�Pj�*�N�T*}Z��y���z�b�Yꊪ�n�7�H��v�^�
# ���b*&�ǵ
# ��monto_estimado����
# &�Ӳ&�ڪ�4��A��4��A�,PTL(�Proceso de CompraGenera Recursos��,��6(Proceso de CompraGenera Recursos�8����4H4��8��r�H>�B������l�	DTx\��3�.���6��Ljz	�D��A�7��3��=�P����c�1�@�1���;4b$��>(v�
# Z/�C�
# ��l	�D�Dz@o0���&�е5tipo_de_operacion���&�ʵ&�ɵ6(Proceso de CompraGenera Recursos,�5schema"%numero_procedimiento%L%nro_saf%descripcion_saf%L%nro_uoc%descripcion_uoc%L%tipo_de_procedimiento%L%	modalidad%L%apartado_directa%L%	ejercicio%fecha_de_publicacion%L%fecha_de_apertura%L%etapa%L%alcance%L%nombre_del_procedimiento%L%objeto_del_procedimiento%L
# �&С&������,&��5fecha_de_publicacion������&��&��6(31/12/2020 10:00:00 a.m.01/04/2020 01:00:00 a.m.,&��#5fecha_de_apertura������&��!&��6(31/12/2099 11:00:00 a.m.01/02/2021 09:00:00 a.m.,&��#5etapa����&��#&��#6(Única	Múltiple,&��#5alcance���&��5nro_uoc������&��&����,&��5descripcion_uoc������&��&�6(0Departamento Contrataciones Córdoba - UOC 40/51.101 - Departamento de Compras y Contrataciones,&�5tipo_de_procedimiento���S�S&ܿ&�6(SubastaConcurso Privado,&ֿ5	modalidad���4�-&�&Ē6(
# Internacional,&��`5nombre_del_procedimiento��Уo��<&�]&��#6([“Servicio de validación de campana de flujo laminar para el HOSPITAL AERONAUTICO CORDOBAS.Mantenimiento  reparación e instalación de pisos  cortinas y mesadas en oficinas,&�֪5objeto_del_procedimiento�������J&���&��`6([“Servicio de validación de campana de flujo laminar para el HOSPITAL AERONAUTICO CORDOBAS.Mantenimiento  reparación e instalación de pisos  cortinas y mesadas en oficinas<&�ǵ
# ��monto_estimado����
# &�Ӳ&�ڪ�4��A��4��A�,&�е5tipo_de_operacion���&�ʵ&�ɵ6(Proceso de CompraGenera Recursos,��������,pandas�{"index_columns": [{"kind": "range", "name": null, "start": 0, "stop": 13549, "step": 1}], "column_indexes": [{"name": null, "field_name": null, "pandas_type": "unicode", "numpy_type": "object", "metadata": {"encoding": "UTF-8"}}], "columns": [{"name": "numero_procedimiento", "field_name": "numero_procedimiento", "pandas_type": "unicode", "numpy_type": "object", "metadata": null}, {"name": "nro_saf", "field_name": "nro_saf", "pandas_type": "int64", "numpy_type": "int64", "metadata": null}, {"name": "descripcion_saf", "field_name": "descripcion_saf", "pandas_type": "unicode", "numpy_type": "object", "metadata": null}, {"name": "nro_uoc", "field_name": "nro_uoc", "pandas_type": "int64", "numpy_type": "int64", "metadata": null}, {"name": "descripcion_uoc", "field_name": "descripcion_uoc", "pandas_type": "unicode", "numpy_type": "object", "metadata": null}, {"name": "tipo_de_procedimiento", "field_name": "tipo_de_procedimiento", "pandas_type": "unicode", "numpy_type": "object", "metadata": null}, {"name": "modalidad", "field_name": "modalidad", "pandas_type": "unicode", "numpy_type": "object", "metadata": null}, {"name": "apartado_directa", "field_name": "apartado_directa", "pandas_type": "unicode", "numpy_type": "object", "metadata": null}, {"name": "ejercicio", "field_name": "ejercicio", "pandas_type": "int64", "numpy_type": "int64", "metadata": null}, {"name": "fecha_de_publicacion", "field_name": "fecha_de_publicacion", "pandas_type": "unicode", "numpy_type": "object", "metadata": null}, {"name": "fecha_de_apertura", "field_name": "fecha_de_apertura", "pandas_type": "unicode", "numpy_type": "object", "metadata": null}, {"name": "etapa", "field_name": "etapa", "pandas_type": "unicode", "numpy_type": "object", "metadata": null}, {"name": "alcance", "field_name": "alcance", "pandas_type": "unicode", "numpy_type": "object", "metadata": null}, {"name": "nombre_del_procedimiento", "field_name": "nombre_del_procedimiento", "pandas_type": "unicode", "numpy_type": "object", "metadata": null}, {"name": "objeto_del_procedimiento", "field_name": "objeto_del_procedimiento", "pandas_type": "unicode", "numpy_type": "object", "metadata": null}, {"name": "monto_estimado", "field_name": "monto_estimado", "pandas_type": "float64", "numpy_type": "float64", "metadata": null}, {"name": "tipo_de_operacion", "field_name": "tipo_de_operacion", "pandas_type": "unicode", "numpy_type": "object", "metadata": null}], "creator": {"library": "pyarrow", "version": "17.0.0"}, "pandas_version": "2.2.2"}ARROW:schema�%... parquet-cpp-arrow version 17.0.0�8(PAR1

# %% [markdown]
# We can compare the size of both files to see how the Parquet file is now smaller than the CSV file. Although this file doesn't contain many rows, it gives us an idea of the significant advantage of using Parquet files.

# %%
print('The size of the CSV file is:')
! stat -c%s /media/notebooks/argentina/convocatorias-2020.csv

# Avro file size with snappy compression
print('The size of the AVRO file is:')
! stat -c%s /media/notebooks/argentina/convocatorias-2020.avro

print('The size of the PARQUET file is:')
! stat -c%s /media/notebooks/argentina/convocatorias-2020.parq
# Out:
# The size of the CSV file is:
# 5675992
# The size of the AVRO file is:
# stat: cannot statx '/media/notebooks/argentina/convocatorias-2020.avro': No such file or directory
# The size of the PARQUET file is:
# 1498335

# %% [markdown]
# ## Read Parquet file with Pandas

# %% [markdown]
# Additionally, Pandas can also read Parquet files and create a DataFrame from them. If we create the DataFrame and compare its content with the DataFrame created from the CSV file, we will see that they are identical.

# %%
# Create a dataFrame from the parquet file
dt_parquet = pd.read_parquet('/media/notebooks/argentina/convocatorias-2020.parq')
dt_parquet.head()
# Out:
#   numero_procedimiento  nro_saf  \
# 0     40/51-0159-LPR19      381
# 1        22-0041-CDI19      250
# 2     40/51-0918-CDI19      381
# 3        92-0075-CDI19      116
# 4      46/1-0005-CDI20      604
#
#                                      descripcion_saf  nro_uoc  \
# 0      381 - Estado Mayor General de La Fuerza Aérea       40
# 1  250 - Caja de Retiros Jubilaciones y Pensiones...       22
# 2      381 - Estado Mayor General de La Fuerza Aérea       40
# 3                          116 - Biblioteca Nacional       92
# 4               604 - Dirección Nacional de Vialidad       46
#
#                                      descripcion_uoc tipo_de_procedimiento  \
# 0    Departamento Contrataciones Córdoba - UOC 40/51    Licitacion Privada
# 1  22 - Dpto de Compras y Suministros - Caja de R...  Contratación Directa
# 2    Departamento Contrataciones Córdoba - UOC 40/51  Contratación Directa
# 3  92 - Departamento de Compras y Contrataciones- BN  Contratación Directa
# 4                     46/01 - 19° Bahía Blanca - DNV  Contratación Directa
#
#        modalidad                          apartado_directa  ejercicio  \
# 0  Sin Modalidad                                      None       2019
# 1  Sin Modalidad  Apartado 1: Compulsa Abreviada Por Monto       2019
# 2  Sin Modalidad  Apartado 1: Compulsa Abreviada Por Monto       2019
# 3  Sin Modalidad  Apartado 1: Compulsa Abreviada Por Monto       2019
# 4  Sin Modalidad  Apartado 1: Compulsa Abreviada Por Monto       2020
#
#        fecha_de_publicacion         fecha_de_apertura  etapa   alcance  \
# 0  02/01/2020 08:00:00 a.m.  10/01/2020 10:00:00 a.m.  Única  Nacional
# 1  02/01/2020 12:00:00 p.m.  13/01/2020 09:00:00 a.m.  Única  Nacional
# 2  02/01/2020 12:00:00 p.m.  13/01/2020 10:00:00 a.m.  Única  Nacional
# 3  02/01/2020 03:00:00 p.m.  27/01/2020 11:00:00 a.m.  Única  Nacional
# 4  02/01/2020 02:00:00 p.m.  08/01/2020 10:00:00 a.m.  Única  Nacional
#
#                             nombre_del_procedimiento  \
# 0  “Adquisición de Elementos de Librería para el ...
# 1  Servicio de seguridad de información sensible ...
# 2  “Servicio Médico Asistencial para Organismos V...
# 3  ADQUISICIÓN DE CAJAS Y REVISTEROS PARA LA DIRE...
# 4  SERVICIO DE ARMADO DE REFUGIO PEATONAL (SEGUND...
#
#                             objeto_del_procedimiento  monto_estimado  \
# 0  “Adquisición de Elementos de Librería para el ...      1957142.84
# 1  Servicio de seguridad de información sensible ...       119915.25
# 2  “Servicio Médico Asistencial para Organismos V...        99000.00
# 3  ADQUISICIÓN DE CAJAS Y REVISTEROS PARA LA DIRE...      1450050.00
# 4             SERVICIO DE ARMADO DE REFUGIO PEATONAL       684000.00
#
#    tipo_de_operacion
# 0  Proceso de Compra
# 1  Proceso de Compra
# 2  Proceso de Compra
# 3  Proceso de Compra
# 4  Proceso de Compra

# %% [markdown]
# ## Extract the Schema from a Parquet File

# %% [markdown]
# An important feature is knowing the schema of a Parquet file. We can use `fastparquet` to find this out, as this library will provide each field along with its associated type.

# %%
from fastparquet import ParquetFile

# Read the file with fastparquet
parquetFile = ParquetFile('/media/notebooks/argentina/convocatorias-2020.parq')

# Get the schema
esquema = parquetFile.schema
print(esquema)
# Out:
# - schema: REQUIRED
# | - numero_procedimiento: BYTE_ARRAY, STRING, UTF8, OPTIONAL
# | - nro_saf: INT64, OPTIONAL
# | - descripcion_saf: BYTE_ARRAY, STRING, UTF8, OPTIONAL
# | - nro_uoc: INT64, OPTIONAL
# | - descripcion_uoc: BYTE_ARRAY, STRING, UTF8, OPTIONAL
# | - tipo_de_procedimiento: BYTE_ARRAY, STRING, UTF8, OPTIONAL
# | - modalidad: BYTE_ARRAY, STRING, UTF8, OPTIONAL
# | - apartado_directa: BYTE_ARRAY, STRING, UTF8, OPTIONAL
# | - ejercicio: INT64, OPTIONAL
# | - fecha_de_publicacion: BYTE_ARRAY, STRING, UTF8, OPTIONAL
# | - fecha_de_apertura: BYTE_ARRAY, STRING, UTF8, OPTIONAL
# | - etapa: BYTE_ARRAY, STRING, UTF8, OPTIONAL
# | - alcance: BYTE_ARRAY, STRING, UTF8, OPTIONAL
# | - nombre_del_procedimiento: BYTE_ARRAY, STRING, UTF8, OPTIONAL
# | - objeto_del_procedimiento: BYTE_ARRAY, STRING, UTF8, OPTIONAL
# | - monto_estimado: DOUBLE, OPTIONAL
#   - tipo_de_operacion: BYTE_ARRAY, STRING, UTF8, OPTIONAL
